# %%
print("hello")
# Out:
# hello

# %%
print('chitra')
# Out:
# chitra

# %%
print('It\'s working')
# Out:
# It's working

# %%
print('He said "Hello"')
# Out:
# He said "Hello"

# %%
print("It's working")
# Out:
# It's working

# %%
print('Hi ' 'world')
# Out:
# Hi world

# %%
Num=[10,20,30,40]
